# %%
import pandas as pd

defra = pd.read_excel("guides_and_dbs/DEFRA_conversion-factors-2021-flat-file-automatic-processing.xlsm", 
                      sheet_name="Factors by Category", header=4)

# Step 1: Load using header from row 1 (row index = 1)
agribalyse_df = pd.read_excel("guides_and_dbs/AGRIBALYSE3.0.1_vf.xlsm", sheet_name="Synthese", header=1)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
defra
# Out:
#         Scope     Level 1        Level 2   Level 3 Level 4        Column Text  \
# 0     Scope 1       Fuels  Gaseous fuels    Butane     NaN  Energy - Gross CV
# 1     Scope 1       Fuels  Gaseous fuels    Butane     NaN  Energy - Gross CV
# 2     Scope 1       Fuels  Gaseous fuels    Butane     NaN  Energy - Gross CV
# 3     Scope 1       Fuels  Gaseous fuels    Butane     NaN  Energy - Gross CV
# 4     Scope 1       Fuels  Gaseous fuels    Butane     NaN    Energy - Net CV
# ...       ...         ...            ...       ...     ...                ...
# 7602  Scope 3  Hotel stay     Hotel stay  Maldives     NaN                NaN
# 7603  Scope 3  Hotel stay     Hotel stay      Oman     NaN                NaN
# 7604  Scope 3  Hotel stay     Hotel stay   Romania     NaN                NaN
# 7605      NaN         NaN            NaN       NaN     NaN                NaN
# 7606      NaN         END            NaN       NaN     NaN                NaN
#
#         UOM (simple)             UOM      GHG                   Lookup  \
# 0                kWh  kWh (Gross CV)  kg CO2e    Butane kWh (Gross CV)
# 1                kWh  kWh (Gross CV)   kg CH4    Butane kWh (Gross CV)
# 2                kWh  kWh (Gross CV)   kg CO2    Butane kWh (Gross CV)
# 3                kWh  kWh (Gross CV)   kg N2O    Butane kWh (Gross CV)
# 4                kWh    kWh (Net CV)  kg CO2e      Butane kWh (Net CV)
# ...              ...             ...      ...                      ...
# 7602  Room per night  Room per night  kg CO2e  Maldives Room per night
# 7603  Room per night  Room per night  kg CO2e      Oman Room per night
# 7604  Room per night  Room per night  kg CO2e   Romania Room per night
# 7605             NaN             NaN      NaN                      NaN
# 7606             NaN             NaN      NaN                      END
#
#      GHG Conversion Factor 2021
# 0                        0.2224
# 1                       0.00017
# 2                        0.2221
# 3                       0.00013
# 4                       0.24106
# ...                         ...
# 7602                      183.3
# 7603                          0
# 7604                       25.5
# 7605                        NaN
# 7606                        NaN
#
# [7607 rows x 11 columns]

# %%
defra[
    defra["Level 3"].astype(str).str.contains("natural", case=False, na=False)
]
# Out:
#         Scope     Level 1             Level 2  \
# 64    Scope 1       Fuels       Gaseous fuels
# 65    Scope 1       Fuels       Gaseous fuels
# 66    Scope 1       Fuels       Gaseous fuels
# 67    Scope 1       Fuels       Gaseous fuels
# 68    Scope 1       Fuels       Gaseous fuels
# 69    Scope 1       Fuels       Gaseous fuels
# 70    Scope 1       Fuels       Gaseous fuels
# 71    Scope 1       Fuels       Gaseous fuels
# 72    Scope 1       Fuels       Gaseous fuels
# 73    Scope 1       Fuels       Gaseous fuels
# 74    Scope 1       Fuels       Gaseous fuels
# 75    Scope 1       Fuels       Gaseous fuels
# 76    Scope 1       Fuels       Gaseous fuels
# 77    Scope 1       Fuels       Gaseous fuels
# 78    Scope 1       Fuels       Gaseous fuels
# 79    Scope 1       Fuels       Gaseous fuels
# 2758  Scope 3  WTT- fuels  WTT- gaseous fuels
# 2759  Scope 3  WTT- fuels  WTT- gaseous fuels
# 2760  Scope 3  WTT- fuels  WTT- gaseous fuels
# 2761  Scope 3  WTT- fuels  WTT- gaseous fuels
# 7067  Scope 1       Fuels       Gaseous fuels
# 7068  Scope 1       Fuels       Gaseous fuels
# 7069  Scope 1       Fuels       Gaseous fuels
# 7070  Scope 1       Fuels       Gaseous fuels
# 7071  Scope 1       Fuels       Gaseous fuels
# 7072  Scope 1       Fuels       Gaseous fuels
# 7073  Scope 1       Fuels       Gaseous fuels
# 7074  Scope 1       Fuels       Gaseous fuels
# 7075  Scope 1       Fuels       Gaseous fuels
# 7076  Scope 1       Fuels       Gaseous fuels
# 7077  Scope 1       Fuels       Gaseous fuels
# 7078  Scope 1       Fuels       Gaseous fuels
# 7079  Scope 1       Fuels       Gaseous fuels
# 7080  Scope 1       Fuels       Gaseous fuels
# 7081  Scope 1       Fuels       Gaseous fuels
# 7082  Scope 1       Fuels       Gaseous fuels
# 7083  Scope 3  WTT- fuels  WTT- gaseous fuels
# 7084  Scope 3  WTT- fuels  WTT- gaseous fuels
# 7085  Scope 3  WTT- fuels  WTT- gaseous fuels
# 7086  Scope 3  WTT- fuels  WTT- gaseous fuels
#
#                                Level 3 Level 4        Column Text  \
# 64                         Natural gas     NaN  Energy - Gross CV
# 65                         Natural gas     NaN  Energy - Gross CV
# 66                         Natural gas     NaN  Energy - Gross CV
# 67                         Natural gas     NaN  Energy - Gross CV
# 68                         Natural gas     NaN    Energy - Net CV
# 69                         Natural gas     NaN    Energy - Net CV
# 70                         Natural gas     NaN    Energy - Net CV
# 71                         Natural gas     NaN    Energy - Net CV
# 72                         Natural gas     NaN             Volume
# 73                         Natural gas     NaN             Volume
# 74                         Natural gas     NaN             Volume
# 75                         Natural gas     NaN             Volume
# 76                         Natural gas     NaN             Tonnes
# 77                         Natural gas     NaN             Tonnes
# 78                         Natural gas     NaN             Tonnes
# 79                         Natural gas     NaN             Tonnes
# 2758                       Natural Gas     NaN  Energy - Gross CV
# 2759                       Natural Gas     NaN    Energy - Net CV
# 2760                       Natural Gas     NaN             Volume
# 2761                       Natural Gas     NaN             Tonnes
# 7067  Natural gas (100% mineral blend)     NaN  Energy - Gross CV
# 7068  Natural gas (100% mineral blend)     NaN  Energy - Gross CV
# 7069  Natural gas (100% mineral blend)     NaN  Energy - Gross CV
# 7070  Natural gas (100% mineral blend)     NaN  Energy - Gross CV
# 7071  Natural gas (100% mineral blend)     NaN    Energy - Net CV
# 7072  Natural gas (100% mineral blend)     NaN    Energy - Net CV
# 7073  Natural gas (100% mineral blend)     NaN    Energy - Net CV
# 7074  Natural gas (100% mineral blend)     NaN    Energy - Net CV
# 7075  Natural gas (100% mineral blend)     NaN             Volume
# 7076  Natural gas (100% mineral blend)     NaN             Volume
# 7077  Natural gas (100% mineral blend)     NaN             Volume
# 7078  Natural gas (100% mineral blend)     NaN             Volume
# 7079  Natural gas (100% mineral blend)     NaN             Tonnes
# 7080  Natural gas (100% mineral blend)     NaN             Tonnes
# 7081  Natural gas (100% mineral blend)     NaN             Tonnes
# 7082  Natural gas (100% mineral blend)     NaN             Tonnes
# 7083  Natural gas (100% mineral blend)     NaN  Energy - Gross CV
# 7084  Natural gas (100% mineral blend)     NaN    Energy - Net CV
# 7085  Natural gas (100% mineral blend)     NaN             Volume
# 7086  Natural gas (100% mineral blend)     NaN             Tonnes
#
#       UOM (simple)             UOM      GHG  \
# 64             kWh  kWh (Gross CV)  kg CO2e
# 65             kWh  kWh (Gross CV)   kg CH4
# 66             kWh  kWh (Gross CV)   kg CO2
# 67             kWh  kWh (Gross CV)   kg N2O
# 68             kWh    kWh (Net CV)  kg CO2e
# 69             kWh    kWh (Net CV)   kg CH4
# 70             kWh    kWh (Net CV)   kg CO2
# 71             kWh    kWh (Net CV)   kg N2O
# 72    cubic metres    cubic metres  kg CO2e
# 73    cubic metres    cubic metres   kg CH4
# 74    cubic metres    cubic metres   kg CO2
# 75    cubic metres    cubic metres   kg N2O
# 76          tonnes          tonnes  kg CO2e
# 77          tonnes          tonnes   kg CH4
# 78          tonnes          tonnes   kg CO2
# 79          tonnes          tonnes   kg N2O
# 2758           kWh  kWh (Gross CV)  kg CO2e
# 2759           kWh    kWh (Net CV)  kg CO2e
# 2760  cubic metres    cubic metres  kg CO2e
# 2761        tonnes          tonnes  kg CO2e
# 7067           kWh  kWh (Gross CV)  kg CO2e
# 7068           kWh  kWh (Gross CV)   kg CH4
# 7069           kWh  kWh (Gross CV)   kg CO2
# 7070           kWh  kWh (Gross CV)   kg N2O
# 7071           kWh    kWh (Net CV)  kg CO2e
# 7072           kWh    kWh (Net CV)   kg CH4
# 7073           kWh    kWh (Net CV)   kg CO2
# 7074           kWh    kWh (Net CV)   kg N2O
# 7075  cubic metres    cubic metres  kg CO2e
# 7076  cubic metres    cubic metres   kg CH4
# 7077  cubic metres    cubic metres   kg CO2
# 7078  cubic metres    cubic metres   kg N2O
# 7079        tonnes          tonnes  kg CO2e
# 7080        tonnes          tonnes   kg CH4
# 7081        tonnes          tonnes   kg CO2
# 7082        tonnes          tonnes   kg N2O
# 7083           kWh  kWh (Gross CV)  kg CO2e
# 7084           kWh    kWh (Net CV)  kg CO2e
# 7085  cubic metres    cubic metres  kg CO2e
# 7086        tonnes          tonnes  kg CO2e
#
#                                                Lookup  \
# 64                         Natural gas kWh (Gross CV)
# 65                         Natural gas kWh (Gross CV)
# 66                         Natural gas kWh (Gross CV)
# 67                         Natural gas kWh (Gross CV)
# 68                           Natural gas kWh (Net CV)
# 69                           Natural gas kWh (Net CV)
# 70                           Natural gas kWh (Net CV)
# 71                           Natural gas kWh (Net CV)
# 72                           Natural gas cubic metres
# 73                           Natural gas cubic metres
# 74                           Natural gas cubic metres
# 75                           Natural gas cubic metres
# 76                                 Natural gas tonnes
# 77                                 Natural gas tonnes
# 78                                 Natural gas tonnes
# 79                                 Natural gas tonnes
# 2758                       Natural Gas kWh (Gross CV)
# 2759                         Natural Gas kWh (Net CV)
# 2760                         Natural Gas cubic metres
# 2761                               Natural Gas tonnes
# 7067  Natural gas (100% mineral blend) kWh (Gross CV)
# 7068  Natural gas (100% mineral blend) kWh (Gross CV)
# 7069  Natural gas (100% mineral blend) kWh (Gross CV)
# 7070  Natural gas (100% mineral blend) kWh (Gross CV)
# 7071    Natural gas (100% mineral blend) kWh (Net CV)
# 7072    Natural gas (100% mineral blend) kWh (Net CV)
# 7073    Natural gas (100% mineral blend) kWh (Net CV)
# 7074    Natural gas (100% mineral blend) kWh (Net CV)
# 7075    Natural gas (100% mineral blend) cubic metres
# 7076    Natural gas (100% mineral blend) cubic metres
# 7077    Natural gas (100% mineral blend) cubic metres
# 7078    Natural gas (100% mineral blend) cubic metres
# 7079          Natural gas (100% mineral blend) tonnes
# 7080          Natural gas (100% mineral blend) tonnes
# 7081          Natural gas (100% mineral blend) tonnes
# 7082          Natural gas (100% mineral blend) tonnes
# 7083  Natural gas (100% mineral blend) kWh (Gross CV)
# 7084    Natural gas (100% mineral blend) kWh (Net CV)
# 7085    Natural gas (100% mineral blend) cubic metres
# 7086          Natural gas (100% mineral blend) tonnes
#
#      GHG Conversion Factor 2021
# 64                      0.18316
# 65                      0.00025
# 66                      0.18282
# 67                       0.0001
# 68                      0.20297
# 69                      0.00028
# 70                      0.20258
# 71                      0.00011
# 72                      2.02135
# 73                      0.00274
# 74                      2.01754
# 75                      0.00107
# 76                      2538.48
# 77                         3.44
# 78                      2533.69
# 79                         1.34
# 2758                    0.03135
# 2759                    0.03474
# 2760                    0.34593
# 2761                  434.42892
# 7067                    0.18438
# 7068                    0.00025
# 7069                    0.18403
# 7070                     0.0001
# 7071                    0.20431
# 7072                    0.00028
# 7073                    0.20393
# 7074                    0.00011
# 7075                    2.03473
# 7076                    0.00274
# 7077                    2.03092
# 7078                    0.00107
# 7079                    2555.28
# 7080                       3.44
# 7081                    2550.49
# 7082                       1.34
# 7083                    0.03135
# 7084                    0.03474
# 7085                    0.34593
# 7086                  434.42892

# %%
defra[
    defra["Level 3"].astype(str).str.contains("fertili", case=False, na=False)
]
# Out:
# Empty DataFrame
# Columns: [Scope, Level 1, Level 2, Level 3, Level 4, Column Text, UOM (simple), UOM, GHG, Lookup, GHG Conversion Factor 2021]
# Index: []
