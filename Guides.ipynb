# %%
import pandas as pd

defra = pd.read_excel("guides_and_dbs/DEFRA_conversion-factors-2021-flat-file-automatic-processing.xlsm", 
                      sheet_name="Factors by Category", header=4)

# Step 1: Load using header from row 1 (row index = 1)
agribalyse_df = pd.read_excel("guides_and_dbs/AGRIBALYSE3.0.1_vf.xlsm", sheet_name="Synthese", header=1)

bio = pd.read_excel("guides_and_dbs/BioGrace_standard_values_-_version_4_-_Public.xlsm", 
                    sheet_name="Standard values", header=9)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 9
#       6 # Step 1: Load using header from row 1 (row index = 1)
#       7 agribalyse_df = pd.read_excel("guides_and_dbs/AGRIBALYSE3.0.1_vf.xlsm", sheet_name="Synthese", header=1)
# ----> 9 bio = pd.read_excel("guides_and_dbs/BioGrace_standard_values_-_version_4_-_Public.xlsm",
#      10                     sheet_name="Factors by Category", header=9)
#
# ...

# %%
# bio = pd.read_excel("guides_and_dbs/BioGrace_standard_values_-_version_4_-_Public.xlsm", 
#                     sheet_name="Standard values", 
#                     header=None,  # don't treat any row as column names yet
#                     skiprows=5)   # skip top rows to reach actual data

# bio

# %%
agribalyse_df = agribalyse_df.loc[:,"LCI Name":"Changement climatique (kg CO2 eq/kg de produit)"]

# %%
agribalyse_df[agribalyse_df["LCI Name"].astype(str).str.contains("cocoa", case=False, na=False)]
# Out:
#                                                LCI Name  \
# 130                                        Cocoa butter
# 271   Instant cocoa or chocolate beverage, with suga...
# 272   Instant cocoa or chocolate beverage, with suga...
# 361        Cocoa powder, without sugar, powder, instant
# 506   Dark chocolate bar, more than 40% cocoa, for c...
# 507             Dark chocolate bar, more than 70% cocoa
# 508             Dark chocolate bar, less than 70% cocoa
# 1895  Cocoa or chocolate powder, for beverages, with...
# 1896  Cocoa or chocolate powder, for beverages, with...
# 1897  Cocoa or chocolate powder, for beverages, with...
# 2035  Shortbread cookie with cocoa or chocolate, or ...
#
#                 Saisonnalité  Transport par avion\n(1 : par avion)  \
# 130   mix de consommation FR                                     0
# 271   mix de consommation FR                                     0
# 272   mix de consommation FR                                     0
# ...

# %%
defra[defra["Lookup"].astype(str).str.contains("container", case=False, na=False)]
# Out:
#         Scope                       Level 1          Level 2         Level 3  \
# 3512  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3513  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3514  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3515  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3516  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3517  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 3518  Scope 3  WTT- delivery vehs & freight  WTT- cargo ship  Container ship
# 6697  Scope 3              Freighting goods       Cargo ship  Container ship
# 6698  Scope 3              Freighting goods       Cargo ship  Container ship
# 6699  Scope 3              Freighting goods       Cargo ship  Container ship
# 6700  Scope 3              Freighting goods       Cargo ship  Container ship
# ...

# %%
electricity_scope2 = defra[
    (defra["Scope"] == "Scope 2") &
    (
        defra["Level 1"].astype(str).str.contains("electricity", case=False, na=False) |
        defra["Level 2"].astype(str).str.contains("electricity", case=False, na=False) |
        defra["Level 3"].astype(str).str.contains("electricity", case=False, na=False)
    )
]

# %%
electricity_scope2[electricity_scope2["GHG"] == "kg CO2e"]
# Out:
#         Scope                 Level 1                   Level 2  \
# 1968  Scope 2          UK electricity     Electricity generated
# 1972  Scope 2  UK electricity for Evs  Cars (by market segment)
# 1976  Scope 2  UK electricity for Evs  Cars (by market segment)
# 1980  Scope 2  UK electricity for Evs  Cars (by market segment)
# 1984  Scope 2  UK electricity for Evs  Cars (by market segment)
# ...       ...                     ...                       ...
# 2256  Scope 2  UK electricity for Evs                      Vans
# 2260  Scope 2  UK electricity for Evs                      Vans
# 2264  Scope 2  UK electricity for Evs                      Vans
# 2268  Scope 2  UK electricity for Evs                      Vans
# 2272  Scope 2  UK electricity for Evs                      Vans
#
#                          Level 3 Level 4                      Column Text  \
# 1968             Electricity: UK     NaN                              NaN
# ...

# %%
elect_scope2 = defra[
    (defra["Scope"] == "Scope 2") &
    (defra["Level 1"].astype(str).str.contains("UK electricity", case=False, na=False)) &
    (defra["Level 2"].astype(str).str.contains("Electricity generated", case=False, na=False)) &
    (defra["UOM"] == "kWh") &
    (defra["GHG"] == "kg CO2e")
]

# %%
elect_scope2
# Out:
#         Scope         Level 1                Level 2          Level 3 Level 4  \
# 1968  Scope 2  UK electricity  Electricity generated  Electricity: UK     NaN
#
#      Column Text UOM (simple)  UOM      GHG           Lookup  \
# 1968         NaN          kWh  kWh  kg CO2e  Electricity: UK
#
#      GHG Conversion Factor 2021
# 1968                    0.21233

# %%
defra[defra["Level 1"].astype(str).str.contains("storage|warehouse", case=False, na=False)]
# Out:
# Empty DataFrame
# Columns: [Scope, Level 1, Level 2, Level 3, Level 4, Column Text, UOM (simple), UOM, GHG, Lookup, GHG Conversion Factor 2021]
# Index: []
