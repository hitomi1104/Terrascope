# %%
import pandas as pd

defra = pd.read_excel("guides_and_dbs/DEFRA_conversion-factors-2021-flat-file-automatic-processing.xlsm", 
                      sheet_name="Factors by Category", header=4)

# Step 1: Load using header from row 1 (row index = 1)
agribalyse_df = pd.read_excel("guides_and_dbs/AGRIBALYSE3.0.1_vf.xlsm", sheet_name="Synthese", header=1)

bio = pd.read_excel("guides_and_dbs/BioGrace_standard_values_-_version_4_-_Public.xlsm", 
                    sheet_name="Standard values", header=9)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
bio = pd.read_excel("guides_and_dbs/BioGrace_standard_values_-_version_4_-_Public.xlsm", 
                    sheet_name="Standard values", 
                    header=None,  # don't treat any row as column names yet
                    skiprows=5)   # skip top rows to reach actual data

bio
# Out:
#       0                                  1       2            3        4   \
# 0    NaN                                NaN  unit:   gCO2,eq / g  gCO2/kg
# 1    NaN                                NaN     NaN          NaN      NaN
# 2    NaN                                NaN     NaN          NaN      NaN
# 3    NaN  Global Warming Potentials (GWP's)     NaN          NaN      NaN
# 4    NaN                                NaN     CO2            1      NaN
# ..   ...                                ...     ...          ...      ...
# 171  NaN                                NaN     NaN          NaN      NaN
# 172  NaN                                NaN     NaN          NaN      NaN
# 173  NaN                                NaN     NaN          NaN      NaN
# 174  NaN                                NaN     NaN          NaN      NaN
# 175  NaN                                NaN     NaN          NaN      NaN
#
#           5        6           7        8        9   ...       21    22  \
# 0    gCH4/kg  gN2O/kg  gCO2-eq/kg  gCO2/MJ  gCH4/MJ  ...      NaN   NaN
# 1        NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# 2        NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# 3        NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# 4        NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# ..       ...      ...         ...      ...      ...  ...      ...   ...
# 171      NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# 172      NaN      NaN         NaN      NaN      NaN  ...      NaN   NaN
# 173      NaN      NaN         NaN      NaN      NaN  ...  My calc  Urea
# 174      NaN      NaN         NaN      NaN      NaN  ...      0.6  0.65
# 175      NaN      NaN         NaN      NaN      NaN  ...     0.48  0.51
#
#                   23   24   25   26   27   28   29   30
# 0                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4                NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ..               ...  ...  ...  ...  ...  ...  ...  ...
# 171              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 172              NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 173  Transport India  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 174              0.6  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 175             0.48  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [176 rows x 31 columns]

# %%
defra

# %%
defra[
    defra["Level 3"].astype(str).str.contains("biodiesel", case=False, na=False)
]
# Out:
#                   Scope            Level 1       Level 2  \
# 459             Scope 1          Bioenergy       Biofuel
# 460             Scope 1          Bioenergy       Biofuel
# 461             Scope 1          Bioenergy       Biofuel
# 465             Scope 1          Bioenergy       Biofuel
# 466             Scope 1          Bioenergy       Biofuel
# 467             Scope 1          Bioenergy       Biofuel
# 468             Scope 1          Bioenergy       Biofuel
# 469             Scope 1          Bioenergy       Biofuel
# 470             Scope 1          Bioenergy       Biofuel
# 471             Scope 1          Bioenergy       Biofuel
# 472             Scope 1          Bioenergy       Biofuel
# 473             Scope 1          Bioenergy       Biofuel
# 3529            Scope 3     WTT- bioenergy  WTT- biofuel
# 3530            Scope 3     WTT- bioenergy  WTT- biofuel
# 3531            Scope 3     WTT- bioenergy  WTT- biofuel
# 3535            Scope 3     WTT- bioenergy  WTT- biofuel
# 3536            Scope 3     WTT- bioenergy  WTT- biofuel
# 3537            Scope 3     WTT- bioenergy  WTT- biofuel
# 3538            Scope 3     WTT- bioenergy  WTT- biofuel
# 3539            Scope 3     WTT- bioenergy  WTT- biofuel
# 3540            Scope 3     WTT- bioenergy  WTT- biofuel
# 3541            Scope 3     WTT- bioenergy  WTT- biofuel
# 3542            Scope 3     WTT- bioenergy  WTT- biofuel
# 3543            Scope 3     WTT- bioenergy  WTT- biofuel
# 6979  Outside of Scopes  Outside of scopes       Biofuel
# 6980  Outside of Scopes  Outside of scopes       Biofuel
# 6981  Outside of Scopes  Outside of scopes       Biofuel
# 6985  Outside of Scopes  Outside of scopes       Biofuel
# 6986  Outside of Scopes  Outside of scopes       Biofuel
# 6987  Outside of Scopes  Outside of scopes       Biofuel
# 6988  Outside of Scopes  Outside of scopes       Biofuel
# 6989  Outside of Scopes  Outside of scopes       Biofuel
# 6990  Outside of Scopes  Outside of scopes       Biofuel
# 6991  Outside of Scopes  Outside of scopes       Biofuel
# 6992  Outside of Scopes  Outside of scopes       Biofuel
# 6993  Outside of Scopes  Outside of scopes       Biofuel
#
#                                    Level 3 Level 4 Column Text UOM (simple)  \
# 459                           Biodiesel ME     NaN         NaN           GJ
# 460                           Biodiesel ME     NaN         NaN           kg
# 461                           Biodiesel ME     NaN         NaN       litres
# 465   Biodiesel ME (from used cooking oil)     NaN         NaN           GJ
# 466   Biodiesel ME (from used cooking oil)     NaN         NaN           kg
# 467   Biodiesel ME (from used cooking oil)     NaN         NaN       litres
# 468             Biodiesel ME (from tallow)     NaN         NaN           GJ
# 469             Biodiesel ME (from tallow)     NaN         NaN           kg
# 470             Biodiesel ME (from tallow)     NaN         NaN       litres
# 471                          Biodiesel HVO     NaN         NaN          NaN
# 472                          Biodiesel HVO     NaN         NaN          NaN
# 473                          Biodiesel HVO     NaN         NaN          NaN
# 3529                          Biodiesel ME     NaN         NaN           GJ
# 3530                          Biodiesel ME     NaN         NaN           kg
# 3531                          Biodiesel ME     NaN         NaN       litres
# 3535  Biodiesel ME (from used cooking oil)     NaN         NaN           GJ
# 3536  Biodiesel ME (from used cooking oil)     NaN         NaN           kg
# 3537  Biodiesel ME (from used cooking oil)     NaN         NaN       litres
# 3538            Biodiesel ME (from tallow)     NaN         NaN           GJ
# 3539            Biodiesel ME (from tallow)     NaN         NaN           kg
# 3540            Biodiesel ME (from tallow)     NaN         NaN       litres
# 3541                         Biodiesel HVO     NaN         NaN           GJ
# 3542                         Biodiesel HVO     NaN         NaN           kg
# 3543                         Biodiesel HVO     NaN         NaN       litres
# 6979                          Biodiesel ME     NaN         NaN           GJ
# 6980                          Biodiesel ME     NaN         NaN           kg
# 6981                          Biodiesel ME     NaN         NaN       litres
# 6985  Biodiesel ME (from used cooking oil)     NaN         NaN           GJ
# 6986  Biodiesel ME (from used cooking oil)     NaN         NaN           kg
# 6987  Biodiesel ME (from used cooking oil)     NaN         NaN       litres
# 6988            Biodiesel ME (from tallow)     NaN         NaN           GJ
# 6989            Biodiesel ME (from tallow)     NaN         NaN           kg
# 6990            Biodiesel ME (from tallow)     NaN         NaN       litres
# 6991                         Biodiesel HVO     NaN         NaN           GJ
# 6992                         Biodiesel HVO     NaN         NaN           kg
# 6993                         Biodiesel HVO     NaN         NaN       litres
#
#          UOM      GHG                                       Lookup  \
# 459       GJ  kg CO2e                              Biodiesel ME GJ
# 460       kg  kg CO2e                              Biodiesel ME kg
# 461   litres  kg CO2e                          Biodiesel ME litres
# 465       GJ  kg CO2e      Biodiesel ME (from used cooking oil) GJ
# 466       kg  kg CO2e      Biodiesel ME (from used cooking oil) kg
# 467   litres  kg CO2e  Biodiesel ME (from used cooking oil) litres
# 468       GJ  kg CO2e                Biodiesel ME (from tallow) GJ
# 469       kg  kg CO2e                Biodiesel ME (from tallow) kg
# 470   litres  kg CO2e            Biodiesel ME (from tallow) litres
# 471       GJ  kg CO2e                             Biodiesel HVO GJ
# 472       kg  kg CO2e                             Biodiesel HVO kg
# 473   litres  kg CO2e                         Biodiesel HVO litres
# 3529      GJ  kg CO2e                              Biodiesel ME GJ
# 3530      kg  kg CO2e                              Biodiesel ME kg
# 3531  litres  kg CO2e                          Biodiesel ME litres
# 3535      GJ  kg CO2e      Biodiesel ME (from used cooking oil) GJ
# 3536      kg  kg CO2e      Biodiesel ME (from used cooking oil) kg
# 3537  litres  kg CO2e  Biodiesel ME (from used cooking oil) litres
# 3538      GJ  kg CO2e                Biodiesel ME (from tallow) GJ
# 3539      kg  kg CO2e                Biodiesel ME (from tallow) kg
# 3540  litres  kg CO2e            Biodiesel ME (from tallow) litres
# 3541      GJ  kg CO2e                             Biodiesel HVO GJ
# 3542      kg  kg CO2e                             Biodiesel HVO kg
# 3543  litres  kg CO2e                         Biodiesel HVO litres
# 6979      GJ   kg CO2                              Biodiesel ME GJ
# 6980      kg   kg CO2                              Biodiesel ME kg
# 6981  litres   kg CO2                          Biodiesel ME litres
# 6985      GJ   kg CO2      Biodiesel ME (from used cooking oil) GJ
# 6986      kg   kg CO2      Biodiesel ME (from used cooking oil) kg
# 6987  litres   kg CO2  Biodiesel ME (from used cooking oil) litres
# 6988      GJ   kg CO2                Biodiesel ME (from tallow) GJ
# 6989      kg   kg CO2                Biodiesel ME (from tallow) kg
# 6990  litres   kg CO2            Biodiesel ME (from tallow) litres
# 6991      GJ   kg CO2                             Biodiesel HVO GJ
# 6992      kg   kg CO2                             Biodiesel HVO kg
# 6993  litres   kg CO2                         Biodiesel HVO litres
#
#      GHG Conversion Factor 2021
# 459                     5.05961
# 460                     0.18822
# 461                     0.16751
# 465                     5.05961
# 466                     0.18822
# 467                     0.16751
# 468                     5.05961
# 469                     0.18822
# 470                     0.16751
# 471                     1.03677
# 472                     0.04562
# 473                     0.03558
# 3529                   12.66351
# 3530                    0.47108
# 3531                    0.41926
# 3535                   10.54167
# 3536                    0.39215
# 3537                    0.34901
# 3538                   13.16857
# 3539                    0.48987
# 3540                    0.43598
# 3541                    6.21212
# 3542                    0.27333
# 3543                     0.2132
# 6979                      71.32
# 6980                       2.65
# 6981                       2.36
# 6985                      71.32
# 6986                       2.65
# 6987                       2.36
# 6988                      71.32
# 6989                       2.65
# 6990                       2.36
# 6991                      70.83
# 6992                       3.12
# 6993                       2.43

# %%
defra[
    defra["Level 3"].astype(str).str.contains("fertili", case=False, na=False)
]
# Out:
# Empty DataFrame
# Columns: [Scope, Level 1, Level 2, Level 3, Level 4, Column Text, UOM (simple), UOM, GHG, Lookup, GHG Conversion Factor 2021]
# Index: []
