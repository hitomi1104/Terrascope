# %%
import pandas as pd

# Load file
df = pd.read_excel("raw_data/natural_gas_and_electricity.xlsx")

# %%
df
# Out:
#    Unnamed: 0      Unnamed: 1           Period Natural Gas Electricity  \
# 0         NaN        Location              NaN       MMBTU         KWH
# 1         BU7       Singapore  Jan to Dec 2021       35467     4395600
# 2         BU8       Indonesia  Jan to Dec 2021       34545     6572103
# 3         BU9  United Kingdom  Jan to Dec 2021         NaN      926347
# 4        BU10       Singapore  Jan to Dec 2021       83408         NaN
# 5         NaN             NaN              NaN         NaN         NaN
# 6         NaN             NaN              NaN         NaN         NaN
# 7         NaN             BU9              NaN         NaN         NaN
# 8         NaN           Month              kwh         NaN         NaN
# 9         NaN          202101            76997         NaN         NaN
# 10        NaN          202102            63785         NaN         NaN
# 11        NaN          202103            76969         NaN         NaN
# 12        NaN          202104            72027         NaN         NaN
# 13        NaN          202105            68224         NaN         NaN
# 14        NaN          202106            73343         NaN         NaN
# 15        NaN          202107            14024         NaN         NaN
# 16        NaN          202108            75771         NaN         NaN
# 17        NaN          202109            75868         NaN         NaN
# 18        NaN          202110           181237         NaN         NaN
# 19        NaN          202111            72058         NaN         NaN
# 20        NaN          202112            76044         NaN         NaN
#
#     Electricity.1
# 0   USD Converted
# 1             NaN
# 2             NaN
# 3             NaN
# 4           26902
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN

# %% [markdown]
# ### Data Cleaning

# %%
df.dtypes
# Out:
# Unnamed: 0       object
# Unnamed: 1       object
# Period           object
# Natural Gas      object
# Electricity      object
# Electricity.1    object
# dtype: object

# %%
df.columns = ["Business Unit", "Location", "Period", "Natural Gas (MMBTU)", "Electricity (kWh)", "Electricity Cost"]

df["Natural Gas (MMBTU)"] = pd.to_numeric(df["Natural Gas (MMBTU)"], errors="coerce")
df["Electricity (kWh)"] = pd.to_numeric(df["Electricity (kWh)"], errors="coerce")

# %%
df.head()
# Out:
#   Business Unit        Location           Period  Natural Gas (MMBTU)  \
# 0           NaN        Location              NaN                  NaN
# 1           BU7       Singapore  Jan to Dec 2021              35467.0
# 2           BU8       Indonesia  Jan to Dec 2021              34545.0
# 3           BU9  United Kingdom  Jan to Dec 2021                  NaN
# 4          BU10       Singapore  Jan to Dec 2021              83408.0
#
#    Electricity (kWh) Electricity Cost
# 0                NaN    USD Converted
# 1          4395600.0              NaN
# 2          6572103.0              NaN
# 3           926347.0              NaN
# 4                NaN            26902

# %%
df["Natural Gas (MMBTU)"].value_counts(), df["Electricity (kWh)"].value_counts()
# Out:
# (Natural Gas (MMBTU)
#  35467.0    1
#  34545.0    1
#  83408.0    1
#  Name: count, dtype: int64,
#  Electricity (kWh)
#  4395600.0    1
#  6572103.0    1
#  926347.0     1
#  Name: count, dtype: int64)

# %%
EMISSION_FACTOR_GAS = 0.05311    # tCO2e per MMBTU (natural gas)
EMISSION_FACTOR_ELEC = 0.00023314  # tCO2e per kWh (UK electricity average, 2021)

df["Emissions: Natural Gas (tCO2e)"] = df["Natural Gas (MMBTU)"] * EMISSION_FACTOR_GAS
df["Emissions: Electricity (tCO2e)"] = df["Electricity (kWh)"] * EMISSION_FACTOR_ELEC

# %%
df["Total Scope 2 Emissions (tCO2e)"] = (
    df["Emissions: Natural Gas (tCO2e)"].fillna(0) + 
    df["Emissions: Electricity (tCO2e)"].fillna(0)
)

scope2_summary = df[[
    "Business Unit", "Location", "Natural Gas (MMBTU)", "Electricity (kWh)",
    "Emissions: Natural Gas (tCO2e)", "Emissions: Electricity (tCO2e)", "Total Scope 2 Emissions (tCO2e)"
]]

# %%
scope2_summary
# Out:
#    Business Unit        Location  Natural Gas (MMBTU)  Electricity (kWh)  \
# 0            NaN        Location                  NaN                NaN
# 1            BU7       Singapore              35467.0          4395600.0
# 2            BU8       Indonesia              34545.0          6572103.0
# 3            BU9  United Kingdom                  NaN           926347.0
# 4           BU10       Singapore              83408.0                NaN
# 5            NaN             NaN                  NaN                NaN
# 6            NaN             NaN                  NaN                NaN
# 7            NaN             BU9                  NaN                NaN
# 8            NaN           Month                  NaN                NaN
# 9            NaN          202101                  NaN                NaN
# 10           NaN          202102                  NaN                NaN
# 11           NaN          202103                  NaN                NaN
# 12           NaN          202104                  NaN                NaN
# 13           NaN          202105                  NaN                NaN
# 14           NaN          202106                  NaN                NaN
# 15           NaN          202107                  NaN                NaN
# 16           NaN          202108                  NaN                NaN
# 17           NaN          202109                  NaN                NaN
# 18           NaN          202110                  NaN                NaN
# 19           NaN          202111                  NaN                NaN
# 20           NaN          202112                  NaN                NaN
#
#     Emissions: Natural Gas (tCO2e)  Emissions: Electricity (tCO2e)  \
# 0                              NaN                             NaN
# 1                       1883.65237                     1024.790184
# 2                       1834.68495                     1532.220093
# 3                              NaN                      215.968540
# 4                       4429.79888                             NaN
# 5                              NaN                             NaN
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                             NaN                             NaN
# 11                             NaN                             NaN
# 12                             NaN                             NaN
# 13                             NaN                             NaN
# 14                             NaN                             NaN
# 15                             NaN                             NaN
# 16                             NaN                             NaN
# 17                             NaN                             NaN
# 18                             NaN                             NaN
# 19                             NaN                             NaN
# 20                             NaN                             NaN
#
#     Total Scope 2 Emissions (tCO2e)
# 0                          0.000000
# 1                       2908.442554
# 2                       3366.905043
# 3                        215.968540
# 4                       4429.798880
# 5                          0.000000
# 6                          0.000000
# 7                          0.000000
# 8                          0.000000
# 9                          0.000000
# 10                         0.000000
# 11                         0.000000
# 12                         0.000000
# 13                         0.000000
# 14                         0.000000
# 15                         0.000000
# 16                         0.000000
# 17                         0.000000
# 18                         0.000000
# 19                         0.000000
# 20                         0.000000
